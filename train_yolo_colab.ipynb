# %% [markdown]
# # 🚗 汽车线束防漏扎检测 - YOLOv8 超大杯 (8x) 云端特训
#
# 这份脚本将利用 Google Colab 的免费 Nvidia T4 GPU，对完整的 3500 张工业照片进行 100 轮专业深度训练，带您达到真正的工业级防漏检率！
#
# **⚠️ 注意：由于 8x 模型极其庞大，训练可能需要 10 小时左右。本脚本已自动配置保存到您的 Google 云端硬盘，防止断线丢失心血！**

# %%
# 1. 挂载 Google 云端硬盘 (极其重要！)
# 这样训练生成的 best.pt 会实时保存到您的网盘里。就算您睡着了电脑断网关机，已经炼好的模型也不会丢！
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 2. 安装核心运行环境
# !pip install roboflow ultralytics

# %%
# 3. 从 Roboflow 接口直接下载 3500 张真实工业数据集
from roboflow import Roboflow
rf = Roboflow(api_key="duzPi5MSXNEm9qaoFevP")
project = rf.workspace("projects-hr9jy").project("wire-harness-validation-model")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# 4. 🚀 开启 100 轮超大杯工业级特训！
from ultralytics import YOLO

# 加载超大杯预训练模型 (Extra Large)，追求物理极限的准确率！
model = YOLO('yolov8x.pt')

# 开始全量训练！
# project 设定为直接存入谷歌云盘，防止 Colab 断线清空数据
results = model.train(
    data=f"{dataset.location}/data.yaml",
    epochs=100,
    imgsz=640,
    device=0,
    batch=8,
    project="/content/drive/MyDrive/YOLOv8_WireHarness",  # 实时存入云盘
    name="train_8x"                                      # 文件夹名字
)
# Out:
# Ultralytics 8.4.46 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# 5. 👀 查看最终成绩单
metrics = model.val()
print("\n✅ 训练与评估全部完成！")
print("👉 您现在可以直接去您的 Google 云端硬盘 (Google Drive) 里找 YOLOv8_WireHarness/train_8x/weights/best.pt 下载了。就算没跑完，最新的 weights 也在云盘里！")
